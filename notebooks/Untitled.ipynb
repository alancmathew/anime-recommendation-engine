# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp
from sklearn.metrics.pairwise import cosine_similarity
from tqdm import tqdm
from itertools import combinations
import math
from multiprocessing import Pool
import warnings
from functools import partial

# %%
warnings.filterwarnings("ignore", category=RuntimeWarning)

# %%
def parallelize(groups, func):
    num_workers = 16
    with Pool(num_workers) as p:
        return pd.concat(p.map(func, [group for name, group in groups])).sort_index()

# %%
df = pd.read_pickle('../data/train.pkl.xz')

# anime_corr = pd.read_pickle('../data/anime_corr.pkl.xz')

# %%
df.loc[df.notnull().sum(axis=1) >= 10]
# Out:
# title          .hack//Legend Of The Twilight  .hack//Roots  .hack//SIGN  \
# username
# Anilucard                                NaN           NaN          NaN
# Thallasian                               NaN           NaN          NaN
# shegicaesario                            NaN           NaN          NaN
# bearofwisdom                             NaN           NaN          NaN
# Potatocat11                              NaN           NaN          NaN
# ...                                      ...           ...          ...
# xbirdyx112                          1.871825           NaN          NaN
# liveandlove15                            NaN           NaN          NaN
# crayo                               2.929452           NaN     3.724528
# SendNudes                                NaN           NaN          NaN
# amaiyume                            3.553962           NaN     3.553962
#
# title          009-1  07-Ghost  100 Sleeping Princes & the Kingdom of Dreams  \
# username
# Anilucard        NaN       NaN                                           NaN
# Thallasian       NaN       NaN                                           NaN
# shegicaesario    NaN       NaN                                           NaN
# bearofwisdom     NaN       NaN                                           NaN
# Potatocat11      NaN       NaN                                           NaN
# ...              ...       ...                                           ...
# xbirdyx112       NaN       NaN                                           NaN
# liveandlove15    NaN       NaN                                           NaN
# crayo            NaN       NaN                                           NaN
# SendNudes        NaN       NaN                                           NaN
# amaiyume         NaN       NaN                                           NaN
#
# title          100% Pascal-sensei (2017)  11eyes  \
# username
# Anilucard                            NaN     NaN
# Thallasian                           NaN     NaN
# shegicaesario                        NaN     NaN
# bearofwisdom                         NaN     NaN
# Potatocat11                          NaN     NaN
# ...                                  ...     ...
# xbirdyx112                           NaN     NaN
# liveandlove15                        NaN     NaN
# crayo                                NaN     NaN
# SendNudes                            NaN     NaN
# amaiyume                             NaN     NaN
#
# title          12-Sai: Chiccha na Mune no Tokimeki  \
# username
# Anilucard                                      NaN
# Thallasian                                     NaN
# shegicaesario                                  NaN
# bearofwisdom                                   NaN
# Potatocat11                                    NaN
# ...                                            ...
# xbirdyx112                                     NaN
# liveandlove15                                  NaN
# crayo                                          NaN
# SendNudes                                      NaN
# amaiyume                                       NaN
#
# title          12-Sai: Chiccha na Mune no Tokimeki 2  ...  gdgd Fairies  \
# username                                              ...
# Anilucard                                        NaN  ...           NaN
# Thallasian                                       NaN  ...           NaN
# shegicaesario                                    NaN  ...           NaN
# bearofwisdom                                     NaN  ...           NaN
# Potatocat11                                      NaN  ...           NaN
# ...                                              ...  ...           ...
# xbirdyx112                                       NaN  ...           NaN
# liveandlove15                                    NaN  ...           NaN
# crayo                                            NaN  ...           NaN
# SendNudes                                        NaN  ...           NaN
# amaiyume                                         NaN  ...           NaN
#
# title          gdgd Fairies 2  gdgd men's party  number24  revisions  \
# username
# Anilucard                 NaN               NaN       NaN        NaN
# Thallasian                NaN               NaN       NaN    0.84261
# shegicaesario             NaN               NaN       NaN        NaN
# bearofwisdom              NaN               NaN       NaN        NaN
# Potatocat11               NaN               NaN       NaN        NaN
# ...                       ...               ...       ...        ...
# xbirdyx112                NaN               NaN       NaN        NaN
# liveandlove15             NaN               NaN       NaN        NaN
# crayo                     NaN               NaN       NaN        NaN
# SendNudes                 NaN               NaN       NaN        NaN
# amaiyume                  NaN               NaN       NaN        NaN
#
# title              sola  www.Working!!  xxxHOLiC  xxxHOLiC Kei  ēlDLIVE
# username
# Anilucard           NaN            NaN       NaN           NaN      NaN
# Thallasian          NaN            NaN       NaN           NaN      NaN
# shegicaesario       NaN            NaN       NaN           NaN      NaN
# bearofwisdom        NaN            NaN       NaN           NaN      NaN
# Potatocat11         NaN            NaN       NaN           NaN      NaN
# ...                 ...            ...       ...           ...      ...
# xbirdyx112          NaN            NaN  1.871825           NaN      NaN
# liveandlove15       NaN            NaN       NaN           NaN      NaN
# crayo          2.929452       1.246601       NaN           NaN      NaN
# SendNudes           NaN            NaN       NaN           NaN      NaN
# amaiyume            NaN            NaN       NaN           NaN      NaN
#
# [54664 rows x 4489 columns]
