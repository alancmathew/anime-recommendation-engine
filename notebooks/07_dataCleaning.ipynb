# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
import json
import sqlalchemy as sql

# %%
with open('../tools/credentials.json') as file:
    credentials = json.load(file)
    
username = credentials["dblogin"]["username"]
password = credentials["dblogin"]["password"]

# %%
db_string = f"postgresql://{username}:{password}@192.168.0.3:5432/animeplanet"
db = sql.create_engine(db_string)

# %%
# query = f"""
#         SELECT title, year, avg, status, eps, times_watched, rating, anime_url, username
#         FROM watch_list
#         WHERE rating IS NOT NULL
#         AND year IS NOT NULL
#         AND eps IS NOT NULL
#         AND avg IS NOT NULL
#         AND "type" = 'TV'
#         AND status IN ('Watched', 'Dropped', 'Watching', 'Stalled');
#         """

# df = pd.read_sql(sql.text(query), db)
# df = df.drop_duplicates(['anime_url', 'username'], keep='last', ignore_index=True)
# df.to_csv('../data/watch_list_raw.csv', index=False)

# %%
# %%bash
# cd ../data
# rm watch_list_raw.csv.xz
# xz -vT0 watch_list_raw.csv

# %% [markdown]
# ### Cleaning Anime Data

# %%
anime = pd.read_pickle('../data/anime_raw.pkl.xz')

# %% [markdown]
# #### `num_eps`

# %%
anime['num_eps']
# Out:
# 0                TV (12 eps x 5 min)
# 1               Movie (1 ep x 5 min)
# 2              TV (104 eps x 23 min)
# 3                                Web
# 4              Movie (1 ep x 80 min)
#                     ...
# 17122                   Movie (1 ep)
# 17123     DVD Special (1 ep x 6 min)
# 17124    DVD Special (1 ep x 24 min)
# 17125                    TV (12 eps)
# 17126           Web (20 eps x 2 min)
# Name: num_eps, Length: 17127, dtype: object

# %%
pattern = r"""(?P<type>(?:TV\sSpecial|TV|Movie|OVA|Music\sVideo|Other|DVD\sSpecial|Web)+)(?:\s+\((?P<num_eps>\d+)(?P<is_ongoing>\+)?\seps?(?:\sx\s(?P<duration>\d+)\smin)?\))?"""
tmp = anime['num_eps'].str.extract(pattern)
tmp['is_ongoing'] = tmp['is_ongoing'].notnull()

# %%
anime[['type', 'num_eps', 'is_ongoing', 'duration']] = tmp

# %%
anime
# Out:
#                                                    title num_eps  \
# 0                                     Gag Manga Biyori 2      12
# 1                                               Fu Yu Nu       1
# 2                               Kijeu CSI: Gwahaksusadae     104
# 3                                       Zuoshou Shanglan     NaN
# 4                                            Jeonsa Ryan       1
# ...                                                  ...     ...
# 17122  BanG Dream! Movie: Episode of Roselia - Part I...       1
# 17123                        Yu Yu Hakusho Picture Drama       1
# 17124                Kannagi: If You Are a Shrine Maiden       1
# 17125                             KADO: The Right Answer      12
# 17126                   Yusei High School Astronomy Club      20
#
#                studio start_end_years  season_year  \
# 0             Artland           2006   Summer 2006
# 1                None           2016          None
# 2                None    2012 - 2014          None
# 3                None            TBA          None
# 4                None           1997          None
# ...               ...             ...          ...
# 17122        SANZIGEN           2021          None
# 17123         Pierrot           2009          None
# 17124    A-1 Pictures           2009          None
# 17125  Toei Animation           2017   Spring 2017
# 17126       AQUA ARIS           2021   Winter 2021
#
#                                   rating  \
# 0          3.583 out of 5 from 233 votes
# 1       7 needed to calculate an average
# 2       7 needed to calculate an average
# 3      10 needed to calculate an average
# 4      10 needed to calculate an average
# ...                                  ...
# 17122       3.528 out of 5 from 31 votes
# 17123      3.528 out of 5 from 811 votes
# 17124    3.528 out of 5 from 2,082 votes
# 17125    3.527 out of 5 from 3,203 votes
# 17126       3.527 out of 5 from 14 votes
#
#                                                 synopsis  \
# 0      The lupine detective Usami-chan is back, and r...
# 1                     No synopsis yet - check back soon!
# 2                     No synopsis yet - check back soon!
# 3                     No synopsis yet - check back soon!
# 4                     No synopsis yet - check back soon!
# ...                                                  ...
# 17122                 No synopsis yet - check back soon!
# 17123                 No synopsis yet - check back soon!
# 17124  One day Shino and Takako find a money clip in ...
# 17125  Koujiro Shindo is a highly-skilled negotiator ...
# 17126                 No synopsis yet - check back soon!
#
#                                                     tags content_warnings  \
# 0      [Comedy, Shounen, Crude, Episodic, Gag, Short ...             None
# 1                            [Chinese Animation, Shorts]             None
# 2                 [Adventure, Mystery, Korean Animation]             None
# 3                [Sports, Basketball, Chinese Animation]             None
# 4      [Adventure, Fantasy, Family Friendly, Korean A...             None
# ...                                                  ...              ...
# 17122                                     [Idols, Music]             None
# 17123  [Comedy, Shounen, Picture Drama, Based on a Ma...             None
# 17124  [Comedy, Fantasy, Shoujo, Japanese Mythology, ...             None
# 17125  [Drama, Sci Fi, Political, CG Animation, Origi...             None
# 17126  [Astronomy, Chibi, School Club, School Life, S...             None
#
#                                                      url         type  \
# 0      https://www.anime-planet.com/anime/gag-manga-b...           TV
# 1            https://www.anime-planet.com/anime/fu-yu-nu        Movie
# 2      https://www.anime-planet.com/anime/kijeu-csi-g...           TV
# 3      https://www.anime-planet.com/anime/zuoshou-sha...          Web
# 4         https://www.anime-planet.com/anime/jeonsa-ryan        Movie
# ...                                                  ...          ...
# 17122  https://www.anime-planet.com/anime/bang-dream-...        Movie
# 17123  https://www.anime-planet.com/anime/yu-yu-hakus...  DVD Special
# 17124  https://www.anime-planet.com/anime/kannagi-if-...  DVD Special
# 17125  https://www.anime-planet.com/anime/kado-the-ri...           TV
# 17126  https://www.anime-planet.com/anime/yusei-high-...          Web
#
#        is_ongoing duration
# 0           False        5
# 1           False        5
# 2           False       23
# 3           False      NaN
# 4           False       80
# ...           ...      ...
# 17122       False      NaN
# 17123       False        6
# 17124       False       24
# 17125       False      NaN
# 17126       False        2
#
# [17127 rows x 13 columns]

# %% [markdown]
# #### `start_end_years`

# %%
anime['start_end_years'] = anime['start_end_years'].str.strip()

# %%
anime[['start_year', 'end_year']] = \
    anime['start_end_years'].str.extract(r'(?P<start_year>(?:(?:\d+)|TBA))(?:\s-\s(?P<end_year>(?:(?:\d+)|\?)))?')

# %%
anime['end_year'] = anime['end_year'].replace({'?': 'TBA'})

# %%
anime.loc[anime['end_year'].isnull(), 'end_year'] = \
    anime.loc[anime['end_year'].isnull(), 'start_year']

# %%
anime[['start_year', 'end_year']].isnull().sum()
# Out:
# start_year    0
# end_year      0
# dtype: int64

# %%
del anime['start_end_years']

# %% [markdown]
# #### `season_year`

# %%
anime['season'] = anime['season_year'].str.extract(r'(?P<season>[A-Za-z]+)')
anime = anime.drop(columns=['season_year'])

# %%
anime
# Out:
#                                                    title num_eps  \
# 0                                     Gag Manga Biyori 2      12
# 1                                               Fu Yu Nu       1
# 2                               Kijeu CSI: Gwahaksusadae     104
# 3                                       Zuoshou Shanglan     NaN
# 4                                            Jeonsa Ryan       1
# ...                                                  ...     ...
# 17122  BanG Dream! Movie: Episode of Roselia - Part I...       1
# 17123                        Yu Yu Hakusho Picture Drama       1
# 17124                Kannagi: If You Are a Shrine Maiden       1
# 17125                             KADO: The Right Answer      12
# 17126                   Yusei High School Astronomy Club      20
#
#                studio                             rating  \
# 0             Artland      3.583 out of 5 from 233 votes
# 1                None   7 needed to calculate an average
# 2                None   7 needed to calculate an average
# 3                None  10 needed to calculate an average
# 4                None  10 needed to calculate an average
# ...               ...                                ...
# 17122        SANZIGEN       3.528 out of 5 from 31 votes
# 17123         Pierrot      3.528 out of 5 from 811 votes
# 17124    A-1 Pictures    3.528 out of 5 from 2,082 votes
# 17125  Toei Animation    3.527 out of 5 from 3,203 votes
# 17126       AQUA ARIS       3.527 out of 5 from 14 votes
#
#                                                 synopsis  \
# 0      The lupine detective Usami-chan is back, and r...
# 1                     No synopsis yet - check back soon!
# 2                     No synopsis yet - check back soon!
# 3                     No synopsis yet - check back soon!
# 4                     No synopsis yet - check back soon!
# ...                                                  ...
# 17122                 No synopsis yet - check back soon!
# 17123                 No synopsis yet - check back soon!
# 17124  One day Shino and Takako find a money clip in ...
# 17125  Koujiro Shindo is a highly-skilled negotiator ...
# 17126                 No synopsis yet - check back soon!
#
#                                                     tags content_warnings  \
# 0      [Comedy, Shounen, Crude, Episodic, Gag, Short ...             None
# 1                            [Chinese Animation, Shorts]             None
# 2                 [Adventure, Mystery, Korean Animation]             None
# 3                [Sports, Basketball, Chinese Animation]             None
# 4      [Adventure, Fantasy, Family Friendly, Korean A...             None
# ...                                                  ...              ...
# 17122                                     [Idols, Music]             None
# 17123  [Comedy, Shounen, Picture Drama, Based on a Ma...             None
# 17124  [Comedy, Fantasy, Shoujo, Japanese Mythology, ...             None
# 17125  [Drama, Sci Fi, Political, CG Animation, Origi...             None
# 17126  [Astronomy, Chibi, School Club, School Life, S...             None
#
#                                                      url         type  \
# 0      https://www.anime-planet.com/anime/gag-manga-b...           TV
# 1            https://www.anime-planet.com/anime/fu-yu-nu        Movie
# 2      https://www.anime-planet.com/anime/kijeu-csi-g...           TV
# 3      https://www.anime-planet.com/anime/zuoshou-sha...          Web
# 4         https://www.anime-planet.com/anime/jeonsa-ryan        Movie
# ...                                                  ...          ...
# 17122  https://www.anime-planet.com/anime/bang-dream-...        Movie
# 17123  https://www.anime-planet.com/anime/yu-yu-hakus...  DVD Special
# 17124  https://www.anime-planet.com/anime/kannagi-if-...  DVD Special
# 17125  https://www.anime-planet.com/anime/kado-the-ri...           TV
# 17126  https://www.anime-planet.com/anime/yusei-high-...          Web
#
#        is_ongoing duration start_year end_year  season
# 0           False        5       2006     2006  Summer
# 1           False        5       2016     2016     NaN
# 2           False       23       2012     2014     NaN
# 3           False      NaN        TBA      TBA     NaN
# 4           False       80       1997     1997     NaN
# ...           ...      ...        ...      ...     ...
# 17122       False      NaN       2021     2021     NaN
# 17123       False        6       2009     2009     NaN
# 17124       False       24       2009     2009     NaN
# 17125       False      NaN       2017     2017  Spring
# 17126       False        2       2021     2021  Winter
#
# [17127 rows x 14 columns]

# %% [markdown]
# #### `rating`

# %%
anime['rating'] = anime['rating'].str.replace('.* needed to calculate an average', '', regex=True).replace('', np.NaN)

# %%
anime['rating']
# Out:
# 0          3.583 out of 5 from 233 votes
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#                       ...
# 17122       3.528 out of 5 from 31 votes
# 17123      3.528 out of 5 from 811 votes
# 17124    3.528 out of 5 from 2,082 votes
# 17125    3.527 out of 5 from 3,203 votes
# 17126       3.527 out of 5 from 14 votes
# Name: rating, Length: 17127, dtype: object

# %%
anime[['rating', 'num_votes']] = anime['rating'].str.extract(r'(?P<rating>\d\.?\d*) out of 5 from (?P<num_votes>[\d,]+) votes')
anime['num_votes'] = anime['num_votes'].str.replace(',','')

# %%
anime
# Out:
#                                                    title num_eps  \
# 0                                     Gag Manga Biyori 2      12
# 1                                               Fu Yu Nu       1
# 2                               Kijeu CSI: Gwahaksusadae     104
# 3                                       Zuoshou Shanglan     NaN
# 4                                            Jeonsa Ryan       1
# ...                                                  ...     ...
# 17122  BanG Dream! Movie: Episode of Roselia - Part I...       1
# 17123                        Yu Yu Hakusho Picture Drama       1
# 17124                Kannagi: If You Are a Shrine Maiden       1
# 17125                             KADO: The Right Answer      12
# 17126                   Yusei High School Astronomy Club      20
#
#                studio rating  \
# 0             Artland  3.583
# 1                None    NaN
# 2                None    NaN
# 3                None    NaN
# 4                None    NaN
# ...               ...    ...
# 17122        SANZIGEN  3.528
# 17123         Pierrot  3.528
# 17124    A-1 Pictures  3.528
# 17125  Toei Animation  3.527
# 17126       AQUA ARIS  3.527
#
#                                                 synopsis  \
# 0      The lupine detective Usami-chan is back, and r...
# 1                     No synopsis yet - check back soon!
# 2                     No synopsis yet - check back soon!
# 3                     No synopsis yet - check back soon!
# 4                     No synopsis yet - check back soon!
# ...                                                  ...
# 17122                 No synopsis yet - check back soon!
# 17123                 No synopsis yet - check back soon!
# 17124  One day Shino and Takako find a money clip in ...
# 17125  Koujiro Shindo is a highly-skilled negotiator ...
# 17126                 No synopsis yet - check back soon!
#
#                                                     tags content_warnings  \
# 0      [Comedy, Shounen, Crude, Episodic, Gag, Short ...             None
# 1                            [Chinese Animation, Shorts]             None
# 2                 [Adventure, Mystery, Korean Animation]             None
# 3                [Sports, Basketball, Chinese Animation]             None
# 4      [Adventure, Fantasy, Family Friendly, Korean A...             None
# ...                                                  ...              ...
# 17122                                     [Idols, Music]             None
# 17123  [Comedy, Shounen, Picture Drama, Based on a Ma...             None
# 17124  [Comedy, Fantasy, Shoujo, Japanese Mythology, ...             None
# 17125  [Drama, Sci Fi, Political, CG Animation, Origi...             None
# 17126  [Astronomy, Chibi, School Club, School Life, S...             None
#
#                                                      url         type  \
# 0      https://www.anime-planet.com/anime/gag-manga-b...           TV
# 1            https://www.anime-planet.com/anime/fu-yu-nu        Movie
# 2      https://www.anime-planet.com/anime/kijeu-csi-g...           TV
# 3      https://www.anime-planet.com/anime/zuoshou-sha...          Web
# 4         https://www.anime-planet.com/anime/jeonsa-ryan        Movie
# ...                                                  ...          ...
# 17122  https://www.anime-planet.com/anime/bang-dream-...        Movie
# 17123  https://www.anime-planet.com/anime/yu-yu-hakus...  DVD Special
# 17124  https://www.anime-planet.com/anime/kannagi-if-...  DVD Special
# 17125  https://www.anime-planet.com/anime/kado-the-ri...           TV
# 17126  https://www.anime-planet.com/anime/yusei-high-...          Web
#
#        is_ongoing duration start_year end_year  season num_votes
# 0           False        5       2006     2006  Summer       233
# 1           False        5       2016     2016     NaN       NaN
# 2           False       23       2012     2014     NaN       NaN
# 3           False      NaN        TBA      TBA     NaN       NaN
# 4           False       80       1997     1997     NaN       NaN
# ...           ...      ...        ...      ...     ...       ...
# 17122       False      NaN       2021     2021     NaN        31
# 17123       False        6       2009     2009     NaN       811
# 17124       False       24       2009     2009     NaN      2082
# 17125       False      NaN       2017     2017  Spring      3203
# 17126       False        2       2021     2021  Winter        14
#
# [17127 rows x 15 columns]

# %%
anime['duration'].astype('float').max()
# Out:
# 235.0

# %% [markdown]
# #### Change datatypes

# %%
dtypes_dict = \
{
    'title': 'string',
    'type': 'category',
    'num_eps': 'float32',
    'is_ongoing': 'bool',
    'duration': 'float32',
    'studio': 'category',
    'start_year': 'category',
    'end_year': 'category',
    'season': 'category',
    'rating': 'float32',
    'num_votes': 'float32',
    'synopsis': 'string',
    'tags': 'object',
    'content_warnings': 'object',
    'url': 'string'
}
anime = anime.astype(dtypes_dict)[list(dtypes_dict.keys())]

# %%
anime
# Out:
#                                                    title         type  \
# 0                                     Gag Manga Biyori 2           TV
# 1                                               Fu Yu Nu        Movie
# 2                               Kijeu CSI: Gwahaksusadae           TV
# 3                                       Zuoshou Shanglan          Web
# 4                                            Jeonsa Ryan        Movie
# ...                                                  ...          ...
# 17122  BanG Dream! Movie: Episode of Roselia - Part I...        Movie
# 17123                        Yu Yu Hakusho Picture Drama  DVD Special
# 17124                Kannagi: If You Are a Shrine Maiden  DVD Special
# 17125                             KADO: The Right Answer           TV
# 17126                   Yusei High School Astronomy Club          Web
#
#        num_eps  is_ongoing  duration          studio start_year end_year  \
# 0         12.0       False       5.0         Artland       2006     2006
# 1          1.0       False       5.0             NaN       2016     2016
# 2        104.0       False      23.0             NaN       2012     2014
# 3          NaN       False       NaN             NaN        TBA      TBA
# 4          1.0       False      80.0             NaN       1997     1997
# ...        ...         ...       ...             ...        ...      ...
# 17122      1.0       False       NaN        SANZIGEN       2021     2021
# 17123      1.0       False       6.0         Pierrot       2009     2009
# 17124      1.0       False      24.0    A-1 Pictures       2009     2009
# 17125     12.0       False       NaN  Toei Animation       2017     2017
# 17126     20.0       False       2.0       AQUA ARIS       2021     2021
#
#        season  rating  num_votes  \
# 0      Summer   3.583      233.0
# 1         NaN     NaN        NaN
# 2         NaN     NaN        NaN
# 3         NaN     NaN        NaN
# 4         NaN     NaN        NaN
# ...       ...     ...        ...
# 17122     NaN   3.528       31.0
# 17123     NaN   3.528      811.0
# 17124     NaN   3.528     2082.0
# 17125  Spring   3.527     3203.0
# 17126  Winter   3.527       14.0
#
#                                                 synopsis  \
# 0      The lupine detective Usami-chan is back, and r...
# 1                     No synopsis yet - check back soon!
# 2                     No synopsis yet - check back soon!
# 3                     No synopsis yet - check back soon!
# 4                     No synopsis yet - check back soon!
# ...                                                  ...
# 17122                 No synopsis yet - check back soon!
# 17123                 No synopsis yet - check back soon!
# 17124  One day Shino and Takako find a money clip in ...
# 17125  Koujiro Shindo is a highly-skilled negotiator ...
# 17126                 No synopsis yet - check back soon!
#
#                                                     tags content_warnings  \
# 0      [Comedy, Shounen, Crude, Episodic, Gag, Short ...             None
# 1                            [Chinese Animation, Shorts]             None
# 2                 [Adventure, Mystery, Korean Animation]             None
# 3                [Sports, Basketball, Chinese Animation]             None
# 4      [Adventure, Fantasy, Family Friendly, Korean A...             None
# ...                                                  ...              ...
# 17122                                     [Idols, Music]             None
# 17123  [Comedy, Shounen, Picture Drama, Based on a Ma...             None
# 17124  [Comedy, Fantasy, Shoujo, Japanese Mythology, ...             None
# 17125  [Drama, Sci Fi, Political, CG Animation, Origi...             None
# 17126  [Astronomy, Chibi, School Club, School Life, S...             None
#
#                                                      url
# 0      https://www.anime-planet.com/anime/gag-manga-b...
# 1            https://www.anime-planet.com/anime/fu-yu-nu
# 2      https://www.anime-planet.com/anime/kijeu-csi-g...
# 3      https://www.anime-planet.com/anime/zuoshou-sha...
# 4         https://www.anime-planet.com/anime/jeonsa-ryan
# ...                                                  ...
# 17122  https://www.anime-planet.com/anime/bang-dream-...
# 17123  https://www.anime-planet.com/anime/yu-yu-hakus...
# 17124  https://www.anime-planet.com/anime/kannagi-if-...
# 17125  https://www.anime-planet.com/anime/kado-the-ri...
# 17126  https://www.anime-planet.com/anime/yusei-high-...
#
# [17127 rows x 15 columns]

# %%
anime.to_csv('../data/anime.csv.xz', index=False)
anime.to_pickle('../data/anime.pkl.xz')
anime.to_sql('anime', db, if_exists='replace', index=False, method='multi')

# %% [markdown]
# ### Merging & Additional Cleaning

# %%
watch_list = pd.read_csv('../data/watch_list_raw.csv.xz')
anime = pd.read_pickle('../data/anime.pkl.xz')

watch_list = watch_list.rename(columns={'rating': 'user_rating', 'anime_url':'url'})
anime = anime.rename(columns={'rating': 'avg_rating', 'ongoing': 'is_ongoing'})

# %%
watch_list
# Out:
#                                                      title  year   avg  \
# 0         Day Break Illusion: il sole penetra le illusioni  2013  2.90
# 1                                                 Dog Days  2011  3.50
# 2                                                Dog Days'  2012  3.70
# 3                                          Fantasista Doll  2013  2.47
# 4                           Fate/Kaleid Liner Prisma Illya  2013  3.54
# ...                                                    ...   ...   ...
# 9205777                           The Ancient Magus' Bride  2017  4.39
# 9205778                    The Disastrous Life of Saiki K.  2016  4.47
# 9205779                              The Seven Deadly Sins  2014  4.35
# 9205780  The Seven Deadly Sins: Revival of The Commandm...  2018  4.37
# 9205781                                  Violet Evergarden  2018  4.53
#
#           status  eps  times_watched  user_rating  \
# 0        Watched   13            1.0          3.0
# 1        Watched   13            1.0          3.5
# 2        Watched   13            1.0          3.0
# 3        Watched   12            1.0          2.5
# 4        Watched   10            1.0          3.5
# ...          ...  ...            ...          ...
# 9205777  Watched   24            2.0          5.0
# 9205778  Watched  120            2.0          5.0
# 9205779  Watched   24            1.0          5.0
# 9205780  Watched   24            1.0          5.0
# 9205781  Watched   13            2.0          5.0
#
#                                                        url username
# 0        https://www.anime-planet.com/anime/day-break-i...     Ruth
# 1              https://www.anime-planet.com/anime/dog-days     Ruth
# 2            https://www.anime-planet.com/anime/dog-days-2     Ruth
# 3        https://www.anime-planet.com/anime/fantasista-...     Ruth
# 4        https://www.anime-planet.com/anime/fate-kaleid...     Ruth
# ...                                                    ...      ...
# 9205777  https://www.anime-planet.com/anime/the-ancient...  Rutendo
# 9205778  https://www.anime-planet.com/anime/the-disastr...  Rutendo
# 9205779  https://www.anime-planet.com/anime/the-seven-d...  Rutendo
# 9205780  https://www.anime-planet.com/anime/the-seven-d...  Rutendo
# 9205781  https://www.anime-planet.com/anime/violet-ever...  Rutendo
#
# [9205782 rows x 9 columns]

# %%
anime
# Out:
#                                                    title         type  \
# 0                                     Gag Manga Biyori 2           TV
# 1                                               Fu Yu Nu        Movie
# 2                               Kijeu CSI: Gwahaksusadae           TV
# 3                                       Zuoshou Shanglan          Web
# 4                                            Jeonsa Ryan        Movie
# ...                                                  ...          ...
# 17122  BanG Dream! Movie: Episode of Roselia - Part I...        Movie
# 17123                        Yu Yu Hakusho Picture Drama  DVD Special
# 17124                Kannagi: If You Are a Shrine Maiden  DVD Special
# 17125                             KADO: The Right Answer           TV
# 17126                   Yusei High School Astronomy Club          Web
#
#        num_eps  is_ongoing  duration          studio start_year end_year  \
# 0         12.0       False       5.0         Artland       2006     2006
# 1          1.0       False       5.0             NaN       2016     2016
# 2        104.0       False      23.0             NaN       2012     2014
# 3          NaN       False       NaN             NaN        TBA      TBA
# 4          1.0       False      80.0             NaN       1997     1997
# ...        ...         ...       ...             ...        ...      ...
# 17122      1.0       False       NaN        SANZIGEN       2021     2021
# 17123      1.0       False       6.0         Pierrot       2009     2009
# 17124      1.0       False      24.0    A-1 Pictures       2009     2009
# 17125     12.0       False       NaN  Toei Animation       2017     2017
# 17126     20.0       False       2.0       AQUA ARIS       2021     2021
#
#        season  avg_rating  num_votes  \
# 0      Summer       3.583      233.0
# 1         NaN         NaN        NaN
# 2         NaN         NaN        NaN
# 3         NaN         NaN        NaN
# 4         NaN         NaN        NaN
# ...       ...         ...        ...
# 17122     NaN       3.528       31.0
# 17123     NaN       3.528      811.0
# 17124     NaN       3.528     2082.0
# 17125  Spring       3.527     3203.0
# 17126  Winter       3.527       14.0
#
#                                                 synopsis  \
# 0      The lupine detective Usami-chan is back, and r...
# 1                     No synopsis yet - check back soon!
# 2                     No synopsis yet - check back soon!
# 3                     No synopsis yet - check back soon!
# 4                     No synopsis yet - check back soon!
# ...                                                  ...
# 17122                 No synopsis yet - check back soon!
# 17123                 No synopsis yet - check back soon!
# 17124  One day Shino and Takako find a money clip in ...
# 17125  Koujiro Shindo is a highly-skilled negotiator ...
# 17126                 No synopsis yet - check back soon!
#
#                                                     tags content_warnings  \
# 0      [Comedy, Shounen, Crude, Episodic, Gag, Short ...             None
# 1                            [Chinese Animation, Shorts]             None
# 2                 [Adventure, Mystery, Korean Animation]             None
# 3                [Sports, Basketball, Chinese Animation]             None
# 4      [Adventure, Fantasy, Family Friendly, Korean A...             None
# ...                                                  ...              ...
# 17122                                     [Idols, Music]             None
# 17123  [Comedy, Shounen, Picture Drama, Based on a Ma...             None
# 17124  [Comedy, Fantasy, Shoujo, Japanese Mythology, ...             None
# 17125  [Drama, Sci Fi, Political, CG Animation, Origi...             None
# 17126  [Astronomy, Chibi, School Club, School Life, S...             None
#
#                                                      url
# 0      https://www.anime-planet.com/anime/gag-manga-b...
# 1            https://www.anime-planet.com/anime/fu-yu-nu
# 2      https://www.anime-planet.com/anime/kijeu-csi-g...
# 3      https://www.anime-planet.com/anime/zuoshou-sha...
# 4         https://www.anime-planet.com/anime/jeonsa-ryan
# ...                                                  ...
# 17122  https://www.anime-planet.com/anime/bang-dream-...
# 17123  https://www.anime-planet.com/anime/yu-yu-hakus...
# 17124  https://www.anime-planet.com/anime/kannagi-if-...
# 17125  https://www.anime-planet.com/anime/kado-the-ri...
# 17126  https://www.anime-planet.com/anime/yusei-high-...
#
# [17127 rows x 15 columns]

# %%
left_df = watch_list[['title', 'url', 'username', 'status', 'times_watched', 'user_rating']]
df = left_df.merge(anime.drop(columns=['title', 'type']), how='left', on='url')

# %%
df
# Out:
#                                                      title  \
# 0         Day Break Illusion: il sole penetra le illusioni
# 1                                                 Dog Days
# 2                                                Dog Days'
# 3                                          Fantasista Doll
# 4                           Fate/Kaleid Liner Prisma Illya
# ...                                                    ...
# 9205777                           The Ancient Magus' Bride
# 9205778                    The Disastrous Life of Saiki K.
# 9205779                              The Seven Deadly Sins
# 9205780  The Seven Deadly Sins: Revival of The Commandm...
# 9205781                                  Violet Evergarden
#
#                                                        url username   status  \
# 0        https://www.anime-planet.com/anime/day-break-i...     Ruth  Watched
# 1              https://www.anime-planet.com/anime/dog-days     Ruth  Watched
# 2            https://www.anime-planet.com/anime/dog-days-2     Ruth  Watched
# 3        https://www.anime-planet.com/anime/fantasista-...     Ruth  Watched
# 4        https://www.anime-planet.com/anime/fate-kaleid...     Ruth  Watched
# ...                                                    ...      ...      ...
# 9205777  https://www.anime-planet.com/anime/the-ancient...  Rutendo  Watched
# 9205778  https://www.anime-planet.com/anime/the-disastr...  Rutendo  Watched
# 9205779  https://www.anime-planet.com/anime/the-seven-d...  Rutendo  Watched
# 9205780  https://www.anime-planet.com/anime/the-seven-d...  Rutendo  Watched
# 9205781  https://www.anime-planet.com/anime/violet-ever...  Rutendo  Watched
#
#          times_watched  user_rating  num_eps is_ongoing  duration  \
# 0                  1.0          3.0     13.0      False       NaN
# 1                  1.0          3.5     13.0      False       NaN
# 2                  1.0          3.0     13.0      False       NaN
# 3                  1.0          2.5     12.0      False       NaN
# 4                  1.0          3.5     10.0      False       NaN
# ...                ...          ...      ...        ...       ...
# 9205777            2.0          5.0     24.0      False       NaN
# 9205778            2.0          5.0    120.0      False       4.0
# 9205779            1.0          5.0     24.0      False       NaN
# 9205780            1.0          5.0     24.0      False       NaN
# 9205781            2.0          5.0     13.0      False       NaN
#
#                       studio start_year end_year  season  avg_rating  \
# 0                        AIC       2013     2013  Summer       3.158
# 1                 Seven Arcs       2011     2011  Spring       3.524
# 2                 Seven Arcs       2012     2012  Summer       3.651
# 3        Hoods Entertainment       2013     2013  Summer       2.918
# 4               SILVER LINK.       2013     2013  Summer       3.513
# ...                      ...        ...      ...     ...         ...
# 9205777           WIT Studio       2017     2018    Fall       4.227
# 9205778            J.C.Staff       2016     2016  Summer       4.308
# 9205779         A-1 Pictures       2014     2015    Fall       4.187
# 9205780         A-1 Pictures       2018     2018  Winter       4.210
# 9205781      Kyoto Animation       2018     2018  Winter       4.396
#
#          num_votes                                           synopsis  \
# 0           1980.0  Akari has always known two things: she’s a ski...
# 1           9447.0  In the magical land of Flonyard, animal-eared ...
# 2           5345.0  Three months have passed since Shinku returned...
# 3           1206.0  Uzume Uno was on her way to class one day when...
# 4           5655.0  Illya loves magical girls; but more than anyth...
# ...            ...                                                ...
# 9205777    22637.0  Chise Hitori was a child nobody wanted. Told b...
# 9205778    23850.0  Kusuo Saiki is a typical 16-year-old high scho...
# 9205779    59396.0  The kingdom of Liones is thrown into turmoil w...
# 9205780    27525.0  Only six of the Seven Deadly Sins have been lo...
# 9205781    28521.0  As a child, Violet was used by the military as...
#
#                                                       tags  \
# 0        [Drama, Fantasy, Horror, Magical Girl, Contemp...
# 1        [Action, Adventure, Ecchi, Fantasy, Animal Cha...
# 2        [Action, Adventure, Ecchi, Fantasy, Animal Cha...
# 3        [Magical Girl, Sci Fi, Seinen, Slice of Life, ...
# 4        [Action, Fantasy, Magical Girl, Shounen, Conte...
# ...                                                    ...
# 9205777  [Drama, Fantasy, Romance, Apprenticeship, Cont...
# 9205778  [Comedy, Shounen, Slice of Life, Breaking the ...
# 9205779  [Action, Adventure, Fantasy, Shounen, Demons, ...
# 9205780  [Action, Adventure, Fantasy, Shounen, Demons, ...
# 9205781  [Drama, Lifestyle Change, Melancholy, War, Bas...
#
#                                           content_warnings
# 0                                                     None
# 1                                                     None
# 2                                                     None
# 3                                                     None
# 4                                                     None
# ...                                                    ...
# 9205777  [Animal Abuse, Mature Themes, Physical Abuse, ...
# 9205778                                               None
# 9205779            [Animal Abuse, Mature Themes, Violence]
# 9205780                                         [Violence]
# 9205781                                         [Violence]
#
# [9205782 rows x 18 columns]

# %% [markdown]
# ### Dealing with missing values

# %%
df.isnull().sum()
# Out:
# title                     0
# url                       0
# username                  0
# status                    0
# times_watched        992993
# user_rating               0
# num_eps                 148
# is_ongoing              148
# duration            8871208
# studio                11586
# start_year              148
# end_year                148
# season               244827
# avg_rating              148
# num_votes               148
# synopsis                148
# tags                    385
# content_warnings    5601517
# dtype: int64

# %%
df['times_watched'] = df['times_watched'].fillna(0)

# %%
df = df.loc[df['avg_rating'].notnull()].reset_index(drop=True)

# %%
df.isnull().sum()
# Out:
# title                     0
# url                       0
# username                  0
# status                    0
# times_watched             0
# user_rating               0
# num_eps                   0
# is_ongoing                0
# duration            8871060
# studio                11438
# start_year                0
# end_year                  0
# season               244679
# avg_rating                0
# num_votes                 0
# synopsis                  0
# tags                    237
# content_warnings    5601369
# dtype: int64

# %% [markdown]
# ### Fixing column errors & changing data types

# %%
df.memory_usage(deep=True) / 10**6
# Out:
# Index                  0.000128
# title                714.333238
# url                 1024.793195
# username             607.002817
# status               589.515176
# times_watched         73.645072
# user_rating           73.645072
# num_eps               36.822536
# is_ongoing           294.819120
# duration              36.822536
# studio                18.471786
# start_year             9.216145
# end_year               9.216145
# season                 9.206056
# avg_rating            36.822536
# num_votes             36.822536
# synopsis            7943.215022
# tags                1491.798256
# content_warnings     458.869000
# dtype: float64

# %%
sum(df.memory_usage(deep=True) / 10**6)
# Out:
# 13465.036372

# %%
df.dtypes
# Out:
# title                 object
# url                   object
# username              object
# status                object
# times_watched        float64
# user_rating          float64
# num_eps              float32
# is_ongoing            object
# duration             float32
# studio              category
# start_year          category
# end_year            category
# season              category
# avg_rating           float32
# num_votes            float32
# synopsis              string
# tags                  object
# content_warnings      object
# dtype: object

# %%
df['title'].unique()
# Out:
# array(['Day Break Illusion: il sole penetra le illusioni', 'Dog Days',
#        "Dog Days'", ..., 'The [email\xa0protected]TER',
#        'The [email\xa0protected]STER: Cinderella Girls',
#        'The [email\xa0protected]ER: Xenoglossia'], dtype=object)

# %%
df.loc[df['title'].str.contains('\[email\xa0protected\]'), 'title'].unique()
# Out:
# array(['The [email\xa0protected]',
#        'The [email\xa0protected]: Xenoglossia',
#        'The [email\xa0protected]: Cinderella Girls',
#        'The [email\xa0protected]: Cinderella Girls Second Series',
#        '[email\xa0protected]',
#        'The [email\xa0protected] SideM: Wake Atte Mini!',
#        'The [email\xa0protected] SideM',
#        'The [email\xa0protected]: Cinderella Girls Theater',
#        'The [email\xa0protected]: Cinderella Girls Theater 2nd Season',
#        'The [email\xa0protected]: Cinderella Girls Theater 3rd Season',
#        'The [email\xa0protected]: Cinderella Girls Theater Climax Season',
#        'The iDO[email\xa0protected]', '[email\xa0protected]i',
#        'The [email\xa0protected]R', '[email\xa0protected]anbaranai',
#        'The iD[email\xa0protected]: Cinderella Girls Second Series',
#        'The IDOLM[email\xa0protected]: Cinderella Girls Theater',
#        'The [email\xa0protected]TER: Cinderella Girls Second Series',
#        'Sas[email\xa0protected]', '[email\xa0protected]ranai',
#        'The iD[email\xa0protected]: Cinderella Girls Theater 2nd Season',
#        'The [email\xa0protected]STER: Cinderella Girls Theater 2nd Season',
#        'The [email\xa0protected]TER',
#        'The [email\xa0protected]STER: Cinderella Girls',
#        'The [email\xa0protected]ER: Xenoglossia'], dtype=object)

# %%
df.loc[df['title'].str.contains('\[email\xa0protected\]'), 'url'].unique()
# Out:
# array(['https://www.anime-planet.com/anime/the-idolmaster',
#        'https://www.anime-planet.com/anime/the-idolmster-xenoglossia',
#        'https://www.anime-planet.com/anime/the-idolmaster-cinderella-girls',
#        'https://www.anime-planet.com/anime/the-idolmaster-cinderella-girls-second-series',
#        'https://www.anime-planet.com/anime/sasami-san-at-ganbaranai',
#        'https://www.anime-planet.com/anime/the-idolmaster-side-m-wake-atte-mini',
#        'https://www.anime-planet.com/anime/the-idolmaster-side-m',
#        'https://www.anime-planet.com/anime/the-idolmaster-cinderella-girls-theater',
#        'https://www.anime-planet.com/anime/the-idolmaster-cinderella-girls-theater-2nd-season',
#        'https://www.anime-planet.com/anime/the-idolmaster-cinderella-girls-theater-3rd-season',
#        'https://www.anime-planet.com/anime/the-idolmaster-cinderella-girls-theater-climax-season'],
#       dtype=object)

# %%
url_title_map = \
{
    'https://www.anime-planet.com/anime/the-idolmaster': 'The iDOLM@STER',
    'https://www.anime-planet.com/anime/sasami-san-at-ganbaranai': 'Sasami-san@Ganbaranai',
    'https://www.anime-planet.com/anime/the-idolmster-xenoglossia': 'The iDOLM@STER: Xenoglossia',
    'https://www.anime-planet.com/anime/the-idolmaster-cinderella-girls': 'The iDOLM@STER: Cinderella Girls',
    'https://www.anime-planet.com/anime/the-idolmaster-cinderella-girls-second-series': 
                                                            'The iDOLM@STER: Cinderella Girls Second Series',
    'https://www.anime-planet.com/anime/the-idolmaster-cinderella-girls-theater': 'The IDOLM@STER: Cinderella Girls Theater',
    'https://www.anime-planet.com/anime/the-idolmaster-side-m': 'The iDOLM@STER SideM',
    'https://www.anime-planet.com/anime/the-idolmaster-cinderella-girls-theater-2nd-season': 
                                                            'The iDOLM@STER: Cinderella Girls Theater 2nd Season',
    'https://www.anime-planet.com/anime/the-idolmaster-cinderella-girls-theater-3rd-season':
                                                            'The iDOLM@STER: Cinderella Girls Theater 3rd Season',
    'https://www.anime-planet.com/anime/the-idolmaster-cinderella-girls-theater-climax-season':
                                                            'The iDOLM@STER: Cinderella Girls Theater Climax Season',
    'https://www.anime-planet.com/anime/the-idolmaster-side-m-wake-atte-mini': 'The iDOLM@STER SideM: Wake Atte Mini!'
}

# %%
df.loc[df['title'].str.contains('\[email\xa0protected\]'), 'title'] = \
    df.loc[df['title'].str.contains('\[email\xa0protected\]'), 'url'].map(url_title_map)

# %%
df['title'].nunique()
# Out:
# 4473

# %%
df.columns
# Out:
# Index(['title', 'url', 'username', 'status', 'times_watched', 'user_rating',
#        'num_eps', 'is_ongoing', 'duration', 'studio', 'start_year', 'end_year',
#        'season', 'avg_rating', 'num_votes', 'synopsis', 'tags',
#        'content_warnings'],
#       dtype='object')

# %%
df['title'] = df['title'].astype('category')

# %%
df['url'] = df['url'].astype('category')

# %%
df['username'] = df['username'].astype('category')

# %%
df['status'] = pd.Categorical(df['status'], categories=['Dropped', 'Stalled', 'Watching', 'Watched'], ordered=True)

# %%
df['times_watched'] = df['times_watched'].astype('uint16')

# %%
df['user_rating'] = df['user_rating'].astype('float32')

# %%
df['num_eps'] = df['num_eps'].astype('uint16')

# %%
df['is_ongoing'] = df['is_ongoing'].astype('bool')

# %%
df['duration'] = df['duration'].astype('float32')

# %%
df['studio'] = df['studio'].astype('category')

# %%
df['start_year'] = df['start_year'].replace('TBA', np.NaN).astype('float')

# %%
df['end_year'] = df['end_year'].replace('TBA', np.NaN).astype('float')

# %%
df['season'] = pd.Categorical(df['season'], categories=['Winter', 'Spring', 'Summer', 'Fall'], ordered=True)

# %%
df['avg_rating'] = df['avg_rating'].astype('float32')

# %%
df['num_votes'] = df['num_votes'].astype('uint32')

# %%
df['synopsis'] = df['synopsis'].astype('string')

# %%
df.memory_usage(deep=True) / 10**6
# Out:
# Index                  0.000128
# title                 18.893276
# url                   19.044799
# username              48.810999
# status                 9.206063
# times_watched         18.411268
# user_rating           36.822536
# num_eps               18.411268
# is_ongoing             9.205634
# duration              36.822536
# studio                18.471786
# start_year            73.645072
# end_year              73.645072
# season                 9.206056
# avg_rating            36.822536
# num_votes             36.822536
# synopsis            7943.215022
# tags                1491.798256
# content_warnings     458.869000
# dtype: float64

# %%
sum(df.memory_usage(deep=True) / 10**6)
# Out:
# 10358.123843000001

# %%
df
# Out:
#                                                      title  \
# 0         Day Break Illusion: il sole penetra le illusioni
# 1                                                 Dog Days
# 2                                                Dog Days'
# 3                                          Fantasista Doll
# 4                           Fate/Kaleid Liner Prisma Illya
# ...                                                    ...
# 9205629                           The Ancient Magus' Bride
# 9205630                    The Disastrous Life of Saiki K.
# 9205631                              The Seven Deadly Sins
# 9205632  The Seven Deadly Sins: Revival of The Commandm...
# 9205633                                  Violet Evergarden
#
#                                                        url username   status  \
# 0        https://www.anime-planet.com/anime/day-break-i...     Ruth  Watched
# 1              https://www.anime-planet.com/anime/dog-days     Ruth  Watched
# 2            https://www.anime-planet.com/anime/dog-days-2     Ruth  Watched
# 3        https://www.anime-planet.com/anime/fantasista-...     Ruth  Watched
# 4        https://www.anime-planet.com/anime/fate-kaleid...     Ruth  Watched
# ...                                                    ...      ...      ...
# 9205629  https://www.anime-planet.com/anime/the-ancient...  Rutendo  Watched
# 9205630  https://www.anime-planet.com/anime/the-disastr...  Rutendo  Watched
# 9205631  https://www.anime-planet.com/anime/the-seven-d...  Rutendo  Watched
# 9205632  https://www.anime-planet.com/anime/the-seven-d...  Rutendo  Watched
# 9205633  https://www.anime-planet.com/anime/violet-ever...  Rutendo  Watched
#
#          times_watched  user_rating  num_eps  is_ongoing  duration  \
# 0                    1          3.0       13       False       NaN
# 1                    1          3.5       13       False       NaN
# 2                    1          3.0       13       False       NaN
# 3                    1          2.5       12       False       NaN
# 4                    1          3.5       10       False       NaN
# ...                ...          ...      ...         ...       ...
# 9205629              2          5.0       24       False       NaN
# 9205630              2          5.0      120       False       4.0
# 9205631              1          5.0       24       False       NaN
# 9205632              1          5.0       24       False       NaN
# 9205633              2          5.0       13       False       NaN
#
#                       studio  start_year  end_year  season  avg_rating  \
# 0                        AIC      2013.0    2013.0  Summer       3.158
# 1                 Seven Arcs      2011.0    2011.0  Spring       3.524
# 2                 Seven Arcs      2012.0    2012.0  Summer       3.651
# 3        Hoods Entertainment      2013.0    2013.0  Summer       2.918
# 4               SILVER LINK.      2013.0    2013.0  Summer       3.513
# ...                      ...         ...       ...     ...         ...
# 9205629           WIT Studio      2017.0    2018.0    Fall       4.227
# 9205630            J.C.Staff      2016.0    2016.0  Summer       4.308
# 9205631         A-1 Pictures      2014.0    2015.0    Fall       4.187
# 9205632         A-1 Pictures      2018.0    2018.0  Winter       4.210
# 9205633      Kyoto Animation      2018.0    2018.0  Winter       4.396
#
#          num_votes                                           synopsis  \
# 0             1980  Akari has always known two things: she’s a ski...
# 1             9447  In the magical land of Flonyard, animal-eared ...
# 2             5345  Three months have passed since Shinku returned...
# 3             1206  Uzume Uno was on her way to class one day when...
# 4             5655  Illya loves magical girls; but more than anyth...
# ...            ...                                                ...
# 9205629      22637  Chise Hitori was a child nobody wanted. Told b...
# 9205630      23850  Kusuo Saiki is a typical 16-year-old high scho...
# 9205631      59396  The kingdom of Liones is thrown into turmoil w...
# 9205632      27525  Only six of the Seven Deadly Sins have been lo...
# 9205633      28521  As a child, Violet was used by the military as...
#
#                                                       tags  \
# 0        [Drama, Fantasy, Horror, Magical Girl, Contemp...
# 1        [Action, Adventure, Ecchi, Fantasy, Animal Cha...
# 2        [Action, Adventure, Ecchi, Fantasy, Animal Cha...
# 3        [Magical Girl, Sci Fi, Seinen, Slice of Life, ...
# 4        [Action, Fantasy, Magical Girl, Shounen, Conte...
# ...                                                    ...
# 9205629  [Drama, Fantasy, Romance, Apprenticeship, Cont...
# 9205630  [Comedy, Shounen, Slice of Life, Breaking the ...
# 9205631  [Action, Adventure, Fantasy, Shounen, Demons, ...
# 9205632  [Action, Adventure, Fantasy, Shounen, Demons, ...
# 9205633  [Drama, Lifestyle Change, Melancholy, War, Bas...
#
#                                           content_warnings
# 0                                                     None
# 1                                                     None
# 2                                                     None
# 3                                                     None
# 4                                                     None
# ...                                                    ...
# 9205629  [Animal Abuse, Mature Themes, Physical Abuse, ...
# 9205630                                               None
# 9205631            [Animal Abuse, Mature Themes, Violence]
# 9205632                                         [Violence]
# 9205633                                         [Violence]
#
# [9205634 rows x 18 columns]

# %% [markdown]
# ### Save Data

# %%
df.to_pickle('../data/watch_list_clean.pkl')

# %%
# %%bash
# cd ../data
#
# rm watch_list_clean.pkl.xz
# xz -vT14 watch_list_clean.pkl
# Out:
# watch_list_clean.pkl: 78.3 MiB / 544.5 MiB = 0.144, 12 MiB/s, 0:44

# %%
df.to_csv('../data/watch_list_clean.csv', index=False)

# %%
# %%bash
# cd ../data
#
# rm watch_list_clean.csv.xz
# xz -vT14 watch_list_clean.csv
# Out:
# rm: cannot remove 'watch_list_clean.csv.xz': No such file or directory
# watch_list_clean.csv: 302.0 MiB / 7,567.5 MiB = 0.040, 28 MiB/s, 4:30
