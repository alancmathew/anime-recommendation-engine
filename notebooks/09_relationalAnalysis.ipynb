# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


pd.set_option('display.float_format', lambda x: '%.4f' % x)

sns.set_theme(style='whitegrid')
grey = '#aca7a7'
cmap = sns.diverging_palette(10, 500, as_cmap=True)

# %%
df = pd.read_pickle('../data/watch_list_clean.pkl.xz')

# %%
anime = df[['title', 'num_eps', 'is_ongoing', 'duration', 'studio', 'start_year', 
            'end_year', 'season', 'avg_rating', 'num_votes', 'synopsis', 'tags', 'content_warnings', 
            'url']].drop_duplicates(['title', 'url'],
                                    ignore_index=True).sort_values('avg_rating', 
                                                                   ascending=False, 
                                                                   ignore_index=True).copy(deep=True)

# %%
df.columns
# Out:
# Index(['title', 'url', 'username', 'status', 'times_watched', 'user_rating',
#        'num_eps', 'is_ongoing', 'duration', 'studio', 'start_year', 'end_year',
#        'season', 'avg_rating', 'num_votes', 'synopsis', 'tags',
#        'content_warnings'],
#       dtype='object')

# %% [markdown]
# ### `username` ~ `user_rating`

# %%
# username ~ user_rating pivot
pivot = df.pivot_table(index='username', 
                       values='user_rating',
                       aggfunc=['count', 'median', 
                                'mean', 'std', 'max', 'min']).droplevel(1, axis=1)

# %%
pivot.query('count > 10').sort_values('count', ascending=False).head(10)
# Out:
#                    count  median   mean    std    max    min
# username
# Harrt               4046  3.0000 3.0602 1.1144 5.0000 0.5000
# SionBlade           3997  3.0000 3.0878 0.6757 5.0000 1.0000
# Harry5676           3707  3.0000 2.7996 1.3683 5.0000 0.5000
# TRUEGOD             3676  5.0000 5.0000 0.0000 5.0000 5.0000
# MateusCarvalho590   3575  5.0000 4.9773 0.2361 5.0000 1.0000
# MrPaulG2            3206  3.0000 3.1338 0.6418 5.0000 0.5000
# HeavenSloth         3039  3.0000 3.0905 0.9323 5.0000 0.5000
# Twistpop            2747  3.5000 3.3981 0.6835 5.0000 0.5000
# tennis101101        2630  2.0000 2.0036 1.3029 5.0000 0.5000
# Katherine609        2626  3.5000 3.5133 1.0447 5.0000 0.5000

# %%
pivot.query('count > 10').sort_values(['mean', 'count'], ascending=False).head(10)
# Out:
#               count  median   mean    std    max    min
# username
# TRUEGOD        3676  5.0000 5.0000 0.0000 5.0000 5.0000
# negi5845826     816  5.0000 5.0000 0.0000 5.0000 5.0000
# JANITOR04       791  5.0000 5.0000 0.0000 5.0000 5.0000
# tony            781  5.0000 5.0000 0.0000 5.0000 5.0000
# Abdullah5122    753  5.0000 5.0000 0.0000 5.0000 5.0000
# Jimushi         707  5.0000 5.0000 0.0000 5.0000 5.0000
# soulbrazier     668  5.0000 5.0000 0.0000 5.0000 5.0000
# CutManRules     624  5.0000 5.0000 0.0000 5.0000 5.0000
# Redemptiion     555  5.0000 5.0000 0.0000 5.0000 5.0000
# HeartSeed       536  5.0000 5.0000 0.0000 5.0000 5.0000

# %% [markdown]
# Remove the user with username of *TRUEGOD* as they seem to have rated every title (3676 of them) as a 5/5.

# %% [markdown]
# ### `username` ~ `times_watched`

# %%
# username ~ user_rating pivot
pivot = df.pivot_table(index='username', 
                       values='times_watched',
                       aggfunc=['count', 'median', 
                                'mean', 'std', 'max', 'min']).droplevel(1, axis=1)

# %%
pivot.sort_values('max', ascending=False)
# Out:
#                  count  median    mean     std  max  min
# username
# MarikuIshtaru     1393  1.0000  1.0797  4.8324  181    0
# Pejton             489  1.0000  1.1554  5.0319  112    0
# LordDagz69          34 99.0000 78.6765 40.5154   99    0
# Fairouz2001         11  1.0000 45.4545 51.0752   99    1
# abdu6969            31 50.0000 52.7742 32.2973   99    0
# ...                ...     ...     ...     ...  ...  ...
# Thiaron              1  0.0000  0.0000     NaN    0    0
# Sythe06              1  0.0000  0.0000     NaN    0    0
# Mizqu                1  0.0000  0.0000     NaN    0    0
# somewhatsurreal      2  0.0000  0.0000  0.0000    0    0
# RimaIsHyper          1  0.0000  0.0000     NaN    0    0
#
# [117162 rows x 6 columns]

# %% [markdown]
# ### `times_watched` ~ `user_rating`

# %%
df['times_watched'].corr(df['user_rating'])
# Out:
# 0.07280553071580671

# %% [markdown]
# There is a weak, positive correlation between the two variables.
