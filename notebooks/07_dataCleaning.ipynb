# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
import json
import sqlalchemy as sql
import pickle

# %%
with open('../tools/credentials.json') as file:
    credentials = json.load(file)
    
username = credentials["dblogin"]["username"]
password = credentials["dblogin"]["password"]

# %%
db_string = f"postgresql://{username}:{password}@192.168.0.3:5432/animeplanet"
db = sql.create_engine(db_string)

# %%
def count_rows():
    query = f"""
            SELECT COUNT(*)
            FROM watch_list
            WHERE rating IS NOT NULL
            AND "type" = 'TV'
            AND status IN ('Watched', 'Dropped', 'Watching', 'Stalled');
            """
    
    return pd.read_sql(sql.text(query), db)['count'][0]

# %%
def read_sql_chunks(chunksize, start=0):

    num_rows = count_rows()
    print(num_rows)
    
    for offset in range(start, num_rows, chunksize):
        query = f"""
                SELECT title, year, avg, status, eps, times_watched, rating, anime_url, username
                FROM watch_list
                WHERE rating IS NOT NULL
                AND year IS NOT NULL
                AND eps IS NOT NULL
                AND avg IS NOT NULL
                AND "type" = 'TV'
                AND status IN ('Watched', 'Dropped', 'Watching', 'Stalled')
                LIMIT {chunksize} OFFSET {offset};
                """
            
        chunk = pd.read_sql(sql.text(query), db)
        
        yield chunk

# %% [markdown]
# df = pd.DataFrame()
#
# chunksize = 1000000
# sql_chunks = read_sql_chunks(chunksize)
#
# for chunk in tqdm(sql_chunks):
#     df = pd.concat([df, chunk], ignore_index=True)
#
# df.to_csv('../data/watch_list_raw.csv.xz', index=False)

# %%
df = pd.read_csv('../data/watch_list_raw.csv.xz')

# %%
df
# Out:
#                                        title type    year   avg   status  \
# 0                             Yuri!!! on Ice   TV  2016.0  4.32  Watched
# 1                                     Oreimo   TV  2010.0  3.75  Watched
# 2                Ouran High School Host Club   TV  2006.0  4.29  Watched
# 3                              Paradise Kiss   TV  2005.0  3.90  Watched
# 4                             Romeo x Juliet   TV  2007.0  3.84  Watched
# ...                                      ...  ...     ...   ...      ...
# 13971925                    Mysteria Friends   TV  2019.0  3.17  Watched
# 13971926       My Teen Romantic Comedy SNAFU   TV  2013.0  4.25  Watched
# 13971927  My Teen Romantic Comedy SNAFU TOO!   TV  2015.0  4.35  Watched
# 13971928                           New Game!   TV  2016.0  4.08  Watched
# 13971929                          New Game!!   TV  2017.0  4.20  Watched
#
#            eps  times_watched  rating  \
# 0         12.0            2.0     5.0
# 1         12.0            1.0     2.0
# 2         26.0            1.0     4.0
# 3         12.0            1.0     3.5
# 4         24.0            1.0     4.5
# ...        ...            ...     ...
# 13971925  10.0            1.0     5.0
# 13971926  13.0            2.0     5.0
# 13971927  13.0            1.0     5.0
# 13971928  12.0            1.0     5.0
# 13971929  12.0            1.0     5.0
#
#                                                   anime_url     username  \
# 0            https://www.anime-planet.com/anime/yuri-on-ice  ironiaburra
# 1                 https://www.anime-planet.com/anime/oreimo      bambina
# 2         https://www.anime-planet.com/anime/ouran-high-...      bambina
# 3          https://www.anime-planet.com/anime/paradise-kiss      bambina
# 4         https://www.anime-planet.com/anime/romeo-x-juliet      bambina
# ...                                                     ...          ...
# 13971925  https://www.anime-planet.com/anime/mysteria-fr...        Imica
# 13971926  https://www.anime-planet.com/anime/my-teen-rom...        Imica
# 13971927  https://www.anime-planet.com/anime/my-teen-rom...        Imica
# 13971928        https://www.anime-planet.com/anime/new-game        Imica
# 13971929      https://www.anime-planet.com/anime/new-game-2        Imica
#
#                                                  origin_url
# 0         https://www.anime-planet.com/users/ironiaburra...
# 1         https://www.anime-planet.com/users/bambina/ani...
# 2         https://www.anime-planet.com/users/bambina/ani...
# 3         https://www.anime-planet.com/users/bambina/ani...
# 4         https://www.anime-planet.com/users/bambina/ani...
# ...                                                     ...
# 13971925  https://www.anime-planet.com/users/Imica/anime...
# 13971926  https://www.anime-planet.com/users/Imica/anime...
# 13971927  https://www.anime-planet.com/users/Imica/anime...
# 13971928  https://www.anime-planet.com/users/Imica/anime...
# 13971929  https://www.anime-planet.com/users/Imica/anime...
#
# [13971930 rows x 11 columns]

# %% [markdown]
# ### Dealing with missing values

# %%
df.isnull().sum()
# Out:
# title                  0
# type                   0
# year                 110
# avg                 1709
# status                 0
# eps               207075
# times_watched    1684920
# rating                 0
# anime_url              0
# username               0
# origin_url             0
# dtype: int64

# %%
df['times_watched'] = df['times_watched'].fillna(0)

# %%
df = df.loc[df['eps'].notnull() & 
            df['avg'].notnull() &
            df['year'].notnull()].drop(columns=['type', 'origin_url']).reset_index(drop=True)

# %%
df
# Out:
#                                        title    year   avg   status   eps  \
# 0                             Yuri!!! on Ice  2016.0  4.32  Watched  12.0
# 1                                     Oreimo  2010.0  3.75  Watched  12.0
# 2                Ouran High School Host Club  2006.0  4.29  Watched  26.0
# 3                              Paradise Kiss  2005.0  3.90  Watched  12.0
# 4                             Romeo x Juliet  2007.0  3.84  Watched  24.0
# ...                                      ...     ...   ...      ...   ...
# 13763145                    Mysteria Friends  2019.0  3.17  Watched  10.0
# 13763146       My Teen Romantic Comedy SNAFU  2013.0  4.25  Watched  13.0
# 13763147  My Teen Romantic Comedy SNAFU TOO!  2015.0  4.35  Watched  13.0
# 13763148                           New Game!  2016.0  4.08  Watched  12.0
# 13763149                          New Game!!  2017.0  4.20  Watched  12.0
#
#           times_watched  rating  \
# 0                   2.0     5.0
# 1                   1.0     2.0
# 2                   1.0     4.0
# 3                   1.0     3.5
# 4                   1.0     4.5
# ...                 ...     ...
# 13763145            1.0     5.0
# 13763146            2.0     5.0
# 13763147            1.0     5.0
# 13763148            1.0     5.0
# 13763149            1.0     5.0
#
#                                                   anime_url     username
# 0            https://www.anime-planet.com/anime/yuri-on-ice  ironiaburra
# 1                 https://www.anime-planet.com/anime/oreimo      bambina
# 2         https://www.anime-planet.com/anime/ouran-high-...      bambina
# 3          https://www.anime-planet.com/anime/paradise-kiss      bambina
# 4         https://www.anime-planet.com/anime/romeo-x-juliet      bambina
# ...                                                     ...          ...
# 13763145  https://www.anime-planet.com/anime/mysteria-fr...        Imica
# 13763146  https://www.anime-planet.com/anime/my-teen-rom...        Imica
# 13763147  https://www.anime-planet.com/anime/my-teen-rom...        Imica
# 13763148        https://www.anime-planet.com/anime/new-game        Imica
# 13763149      https://www.anime-planet.com/anime/new-game-2        Imica
#
# [13763150 rows x 9 columns]

# %% [markdown]
# ### Fixing column errors & changing data types

# %%
df.memory_usage(deep=True) / 10**6
# Out:
# Index               0.000128
# title            1067.704640
# year              110.105200
# avg               110.105200
# status            881.373140
# eps               110.105200
# times_watched     110.105200
# rating            110.105200
# anime_url        1531.970003
# username          907.498866
# dtype: float64

# %%
sum(df.memory_usage(deep=True) / 10**6)
# Out:
# 4939.072776999999

# %%
df.dtypes
# Out:
# title             object
# year             float64
# avg              float64
# status            object
# eps              float64
# times_watched    float64
# rating           float64
# anime_url         object
# username          object
# dtype: object

# %%
df['title'].unique()
# Out:
# array(['Yuri!!! on Ice', 'Oreimo', 'Ouran High School Host Club', ...,
#        'Ikkyuu-san (1978)',
#        'The [email\xa0protected]STER: Cinderella Girls',
#        '[email\xa0protected]i'], dtype=object)

# %%
df.loc[df['title'].str.contains('\[email\xa0protected\]'), 'title'].unique()
# Out:
# array(['The [email\xa0protected]', '[email\xa0protected]',
#        'The [email\xa0protected]: Xenoglossia',
#        'The [email\xa0protected]: Cinderella Girls',
#        'The [email\xa0protected]: Cinderella Girls Second Series',
#        'The [email\xa0protected]: Cinderella Girls Theater',
#        'The [email\xa0protected] SideM',
#        'The [email\xa0protected]: Cinderella Girls Theater 2nd Season',
#        'The [email\xa0protected]: Cinderella Girls Theater 3rd Season',
#        'The [email\xa0protected]: Cinderella Girls Theater Climax Season',
#        'The [email\xa0protected] SideM: Wake Atte Mini!',
#        '[email\xa0protected]anbaranai',
#        'The iD[email\xa0protected]: Cinderella Girls Second Series',
#        'The IDOLM[email\xa0protected]: Cinderella Girls Theater',
#        'The iDO[email\xa0protected]', 'Sas[email\xa0protected]',
#        '[email\xa0protected]ranai', 'The [email\xa0protected]R',
#        'The [email\xa0protected]STER: Cinderella Girls',
#        '[email\xa0protected]i'], dtype=object)

# %%
df.loc[df['title'].str.contains('\[email\xa0protected\]'), 'anime_url'].unique()
# Out:
# array(['https://www.anime-planet.com/anime/the-idolmaster',
#        'https://www.anime-planet.com/anime/sasami-san-at-ganbaranai',
#        'https://www.anime-planet.com/anime/the-idolmster-xenoglossia',
#        'https://www.anime-planet.com/anime/the-idolmaster-cinderella-girls',
#        'https://www.anime-planet.com/anime/the-idolmaster-cinderella-girls-second-series',
#        'https://www.anime-planet.com/anime/the-idolmaster-cinderella-girls-theater',
#        'https://www.anime-planet.com/anime/the-idolmaster-side-m',
#        'https://www.anime-planet.com/anime/the-idolmaster-cinderella-girls-theater-2nd-season',
#        'https://www.anime-planet.com/anime/the-idolmaster-cinderella-girls-theater-3rd-season',
#        'https://www.anime-planet.com/anime/the-idolmaster-cinderella-girls-theater-climax-season',
#        'https://www.anime-planet.com/anime/the-idolmaster-side-m-wake-atte-mini'],
#       dtype=object)

# %%
url_title_map = \
{
    'https://www.anime-planet.com/anime/the-idolmaster': 'The iDOLM@STER',
    'https://www.anime-planet.com/anime/sasami-san-at-ganbaranai': 'Sasami-san@Ganbaranai',
    'https://www.anime-planet.com/anime/the-idolmster-xenoglossia': 'The iDOLM@STER: Xenoglossia',
    'https://www.anime-planet.com/anime/the-idolmaster-cinderella-girls': 'The iDOLM@STER: Cinderella Girls',
    'https://www.anime-planet.com/anime/the-idolmaster-cinderella-girls-second-series': 
                                                            'The iDOLM@STER: Cinderella Girls Second Series',
    'https://www.anime-planet.com/anime/the-idolmaster-cinderella-girls-theater': 'The IDOLM@STER: Cinderella Girls Theater',
    'https://www.anime-planet.com/anime/the-idolmaster-side-m': 'The iDOLM@STER SideM',
    'https://www.anime-planet.com/anime/the-idolmaster-cinderella-girls-theater-2nd-season': 
                                                            'The iDOLM@STER: Cinderella Girls Theater 2nd Season',
    'https://www.anime-planet.com/anime/the-idolmaster-cinderella-girls-theater-3rd-season':
                                                            'The iDOLM@STER: Cinderella Girls Theater 3rd Season',
    'https://www.anime-planet.com/anime/the-idolmaster-cinderella-girls-theater-climax-season':
                                                            'The iDOLM@STER: Cinderella Girls Theater Climax Season',
    'https://www.anime-planet.com/anime/the-idolmaster-side-m-wake-atte-mini': 'The iDOLM@STER SideM: Wake Atte Mini!'
}

# %%
df.loc[df['title'].str.contains('\[email\xa0protected\]'), 'title'] = \
    df.loc[df['title'].str.contains('\[email\xa0protected\]'), 'anime_url'].map(url_title_map)

# %%
df['title'].nunique()
# Out:
# 4489

# %%
df['title'] = df['title'].astype('category')

# %%
df['year'] = df['year'].astype('int')
df['year'] = pd.Categorical(df['year'].astype('int'), categories=sorted(df['year'].unique()), ordered=True)

# %%
df['avg'] = df['avg'].astype('float32')

# %%
df['status'] = pd.Categorical(df['status'], categories=['Dropped', 'Stalled', 'Watching', 'Watched'], ordered=True)

# %%
df['eps'] = df['eps'].astype('uint16')

# %%
df['times_watched'] = df['times_watched'].astype('uint16')

# %%
df['rating'] = df['rating'].astype('float32')

# %%
df['anime_url'] = df['anime_url'].astype('category')

# %%
df['username'] = df['username'].astype('category')

# %%
df.memory_usage(deep=True) / 10**6
# Out:
# Index             0.000128
# title            28.009531
# year             13.765742
# avg              55.052600
# status           13.763579
# eps              27.526300
# times_watched    27.526300
# rating           55.052600
# anime_url        28.161604
# username         66.325478
# dtype: float64

# %%
sum(df.memory_usage(deep=True) / 10**6)
# Out:
# 315.183862

# %%
df
# Out:
#                                        title  year   avg   status  eps  \
# 0                             Yuri!!! on Ice  2016  4.32  Watched   12
# 1                                     Oreimo  2010  3.75  Watched   12
# 2                Ouran High School Host Club  2006  4.29  Watched   26
# 3                              Paradise Kiss  2005  3.90  Watched   12
# 4                             Romeo x Juliet  2007  3.84  Watched   24
# ...                                      ...   ...   ...      ...  ...
# 13763145                    Mysteria Friends  2019  3.17  Watched   10
# 13763146       My Teen Romantic Comedy SNAFU  2013  4.25  Watched   13
# 13763147  My Teen Romantic Comedy SNAFU TOO!  2015  4.35  Watched   13
# 13763148                           New Game!  2016  4.08  Watched   12
# 13763149                          New Game!!  2017  4.20  Watched   12
#
#           times_watched  rating  \
# 0                     2     5.0
# 1                     1     2.0
# 2                     1     4.0
# 3                     1     3.5
# 4                     1     4.5
# ...                 ...     ...
# 13763145              1     5.0
# 13763146              2     5.0
# 13763147              1     5.0
# 13763148              1     5.0
# 13763149              1     5.0
#
#                                                   anime_url     username
# 0            https://www.anime-planet.com/anime/yuri-on-ice  ironiaburra
# 1                 https://www.anime-planet.com/anime/oreimo      bambina
# 2         https://www.anime-planet.com/anime/ouran-high-...      bambina
# 3          https://www.anime-planet.com/anime/paradise-kiss      bambina
# 4         https://www.anime-planet.com/anime/romeo-x-juliet      bambina
# ...                                                     ...          ...
# 13763145  https://www.anime-planet.com/anime/mysteria-fr...        Imica
# 13763146  https://www.anime-planet.com/anime/my-teen-rom...        Imica
# 13763147  https://www.anime-planet.com/anime/my-teen-rom...        Imica
# 13763148        https://www.anime-planet.com/anime/new-game        Imica
# 13763149      https://www.anime-planet.com/anime/new-game-2        Imica
#
# [13763150 rows x 9 columns]

# %% [markdown]
# ### Total Episodes of a show

# %%
url_total_eps_dict = dict(df.groupby('anime_url')['eps'].max())

# %%
df['total_eps'] = df['anime_url'].map(url_total_eps_dict).astype('uint16')

# %%
df
# Out:
#                                        title  year   avg   status  eps  \
# 0                             Yuri!!! on Ice  2016  4.32  Watched   12
# 1                                     Oreimo  2010  3.75  Watched   12
# 2                Ouran High School Host Club  2006  4.29  Watched   26
# 3                              Paradise Kiss  2005  3.90  Watched   12
# 4                             Romeo x Juliet  2007  3.84  Watched   24
# ...                                      ...   ...   ...      ...  ...
# 13763145                    Mysteria Friends  2019  3.17  Watched   10
# 13763146       My Teen Romantic Comedy SNAFU  2013  4.25  Watched   13
# 13763147  My Teen Romantic Comedy SNAFU TOO!  2015  4.35  Watched   13
# 13763148                           New Game!  2016  4.08  Watched   12
# 13763149                          New Game!!  2017  4.20  Watched   12
#
#           times_watched  rating  \
# 0                     2     5.0
# 1                     1     2.0
# 2                     1     4.0
# 3                     1     3.5
# 4                     1     4.5
# ...                 ...     ...
# 13763145              1     5.0
# 13763146              2     5.0
# 13763147              1     5.0
# 13763148              1     5.0
# 13763149              1     5.0
#
#                                                   anime_url     username  \
# 0            https://www.anime-planet.com/anime/yuri-on-ice  ironiaburra
# 1                 https://www.anime-planet.com/anime/oreimo      bambina
# 2         https://www.anime-planet.com/anime/ouran-high-...      bambina
# 3          https://www.anime-planet.com/anime/paradise-kiss      bambina
# 4         https://www.anime-planet.com/anime/romeo-x-juliet      bambina
# ...                                                     ...          ...
# 13763145  https://www.anime-planet.com/anime/mysteria-fr...        Imica
# 13763146  https://www.anime-planet.com/anime/my-teen-rom...        Imica
# 13763147  https://www.anime-planet.com/anime/my-teen-rom...        Imica
# 13763148        https://www.anime-planet.com/anime/new-game        Imica
# 13763149      https://www.anime-planet.com/anime/new-game-2        Imica
#
#           total_eps
# 0                12
# 1                12
# 2                26
# 3                12
# 4                24
# ...             ...
# 13763145         10
# 13763146         13
# 13763147         13
# 13763148         12
# 13763149         12
#
# [13763150 rows x 10 columns]

# %%
sum(df.memory_usage(deep=True) / 10**6)
# Out:
# 342.71016199999997

# %% [markdown]
# ### Save Data

# %%
df.to_csv('../data/watch_list_clean.csv.xz', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-2d63a393a126> in <module>
# ----> 1 df.to_csv('../data/watch_list_clean.csv.xz', index=False)
#
# ~/miniconda3/envs/anime-recommendation-engine/lib/python3.8/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3385         )
#    3386
# -> 3387         return DataFrameRenderer(formatter).to_csv(
#    3388             path_or_buf,
#    3389             line_terminator=line_terminator,
#
# ~/miniconda3/envs/anime-recommendation-engine/lib/python3.8/site-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1081             formatter=self.fmt,
#    1082         )
# -> 1083         csv_formatter.save()
#    1084
#    1085         if created_buffer:
#
# ~/miniconda3/envs/anime-recommendation-engine/lib/python3.8/site-packages/pandas/io/formats/csvs.py in save(self)
#     246             )
#     247
# --> 248             self._save()
#     249
#     250     def _save(self) -> None:
#
# ~/miniconda3/envs/anime-recommendation-engine/lib/python3.8/site-packages/pandas/io/formats/csvs.py in _save(self)
#     251         if self._need_to_save_header:
#     252             self._save_header()
# --> 253         self._save_body()
#     254
#     255     def _save_header(self) -> None:
#
# ~/miniconda3/envs/anime-recommendation-engine/lib/python3.8/site-packages/pandas/io/formats/csvs.py in _save_body(self)
#     289             if start_i >= end_i:
#     290                 break
# --> 291             self._save_chunk(start_i, end_i)
#     292
#     293     def _save_chunk(self, start_i: int, end_i: int) -> None:
#
# ~/miniconda3/envs/anime-recommendation-engine/lib/python3.8/site-packages/pandas/io/formats/csvs.py in _save_chunk(self, start_i, end_i)
#     300
#     301         ix = self.data_index[slicer]._format_native_types(**self._number_format)
# --> 302         libwriters.write_csv_rows(data, ix, self.nlevels, self.cols, self.writer)
#
# pandas/_libs/writers.pyx in pandas._libs.writers.write_csv_rows()
#
# ~/miniconda3/envs/anime-recommendation-engine/lib/python3.8/lzma.py in write(self, data)
#     230         """
#     231         self._check_can_write()
# --> 232         compressed = self._compressor.compress(data)
#     233         self._fp.write(compressed)
#     234         self._pos += len(data)
#
# KeyboardInterrupt:

# %%
df.to_pickle('../data/watch_list_clean.pkl.xz')
